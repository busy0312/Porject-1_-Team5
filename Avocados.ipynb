# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# File to Load
file_to_load = "Resources/avocado.csv"

# Read Avocado File and store into Pandas data frame
avocado_data = pd.read_csv(file_to_load)

# Preview of the DataFrame

avocado_data=pd.DataFrame(avocado_data)

# %%
delete_row = avocado_data[avocado_data["region"]=='TotalUS'].index
avocado_data= avocado_data.drop(delete_row)
avocado_data=avocado_data.drop(columns='Unnamed: 0',axis=1)
avocado_data
# Out:
#              Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1      2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2      2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3      2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4      2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244  2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 18245  2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 18246  2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 18247  2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 18248  2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
avocado_data=avocado_data.rename(
                            columns={"4046":"Hass Small",
                                     "4225":"Hass Large",
                                     "4770":"All sizes",
                                     'AveragePrice':'Average Price',
                                     'type':'Type',
                                     'year':'Year',
                                     'region':'Region'
                                    
                                    })

avocado_data['Total Sales']=''
Total=avocado_data['Average Price']*avocado_data['Total Volume']
avocado_data['Total Sales']=Total
avocado_data
# Out:
#              Date  Average Price  Total Volume  Hass Small  Hass Large  \
# 0      2015-12-27           1.33      64236.62     1036.74    54454.85
# 1      2015-12-20           1.35      54876.98      674.28    44638.81
# 2      2015-12-13           0.93     118220.22      794.70   109149.67
# 3      2015-12-06           1.08      78992.15     1132.00    71976.41
# 4      2015-11-29           1.28      51039.60      941.48    43838.39
# ...           ...            ...           ...         ...         ...
# 18244  2018-02-04           1.63      17074.83     2046.96     1529.20
# 18245  2018-01-28           1.71      13888.04     1191.70     3431.50
# 18246  2018-01-21           1.87      13766.76     1191.92     2452.79
# 18247  2018-01-14           1.93      16205.22     1527.63     2981.04
# 18248  2018-01-07           1.62      17489.58     2894.77     2356.13
#
#        All sizes  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
data15=avocado_data[avocado_data['Year']==2015].groupby('Region')
data16=avocado_data[avocado_data['Year']==2016].groupby('Region')
data17=avocado_data[avocado_data['Year']==2017].groupby('Region')
data18=avocado_data[avocado_data['Year']==2018].groupby('Region')
small5=data15['Hass Small'].max()
small6=data16['Hass Small'].max()
small7=data17['Hass Small'].max()
small8=data18['Hass Small'].max()
hasssmall_sum=pd.DataFrame({"2015": small5,
                            "2016":small6,
                              "2017":small7,
                              "2018":small8
                              })
hasssmall_sum
# Out:
#                            2015        2016        2017        2018
# Region
# Albany                  2819.50    34912.97     5666.60    16361.69
# Atlanta               553198.56   415641.47   442152.50   474887.68
# BaltimoreWashington    93166.54   202958.24   190311.92   139312.12
# Boise                  69544.59    45952.69    60550.46    66653.80
# Boston                  7653.19    85204.27    83640.38    26019.52
# BuffaloRochester        3500.48     4629.34    26274.97    18266.89
# California           4794142.14  2930343.28  3986429.59  4473811.63
# Charlotte              52915.50    63128.71    95176.35    86708.74
# Chicago                69420.04   151462.15   378806.26   257095.68
# CincinnatiDayton       11982.39     7943.24    86072.67   102019.45
# Columbus              111171.46   132004.80   140453.99   112638.98
# DallasFtWorth        1013252.58   766439.13   882268.72   855815.37
# Denver                217715.85   230721.51   239163.63   234995.54
# ...

# %%
large5=data15['Hass Large'].max()
large6=data16['Hass Large'].max()
large7=data17['Hass Large'].max()
large8=data18['Hass Large'].max()
hasslarge_sum=pd.DataFrame({"2015": large5,
                              "2016": large6,
                              "2017":large7,
                              "2018":large8,})
hasslarge_sum
# Out:
#                            2015        2016        2017        2018
# Region
# Albany                109149.67   163570.47   165530.03   195725.06
# Atlanta                92780.33   211776.98   167181.75    60229.21
# BaltimoreWashington   745385.26   804251.93   770463.22   805041.45
# Boise                  36532.33    14822.29    11333.87     8511.49
# Boston                627503.98   698437.70   605624.94   865836.92
# BuffaloRochester       73754.30    97493.47    97167.09    99364.48
# California           3460743.80  3950852.38  3550403.07  4097591.67
# Charlotte              80244.55   160544.54   172311.19    99117.46
# Chicago               824745.44   758581.79   912672.33  1235325.42
# CincinnatiDayton      224967.68   183121.83   181550.84    67966.25
# Columbus               59739.98    55303.67    60090.44    61748.67
# DallasFtWorth         509069.75   411340.37   438041.57   340887.07
# Denver                608156.34   557897.36   502457.31   468889.32
# ...

# %%
all5=data15['All sizes'].max()
all6=data16['All sizes'].max()
all7=data17['All sizes'].max()
all8=data18['All sizes'].max()
allsizes_sum=pd.DataFrame({"2015": all5,
                              "2016": all6,
                              "2017":all7,
                              "2018":all8,})
allsizes_sum
# Out:
#                           2015       2016       2017       2018
# Region
# Albany                 5883.16     426.92    2546.08     143.53
# Atlanta                4251.74    1996.32    3491.08    1831.33
# BaltimoreWashington   83652.48   60290.41   29352.66    5611.56
# Boise                  8434.98   17989.29   23346.13   22490.26
# Boston                13952.56   81859.54   11138.94    6620.69
# BuffaloRochester       6707.85    1784.73     209.65      96.23
# California           273922.36  424389.60  224121.48  151045.33
# Charlotte             80813.88   46282.10   21721.89    6476.93
# Chicago              164884.41  184518.62  224554.50  174975.75
# CincinnatiDayton      23368.18   30149.60   20559.93   19975.22
# Columbus              32383.88   36191.68    5344.74    5329.61
# DallasFtWorth         99900.94  143875.64   97315.69    7862.07
# Denver                29349.34   62908.07   30183.22   16598.60
# Detroit              144745.74  192417.10   84740.62   62078.52
# ...

# %%
x_axis = np.arange(len(allsizes_sum))

# %%
plt.figure(figsize=(16,3))
plt.bar(x_axis, allsizes_sum["2015"], color='r', alpha=0.5, align="center")
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, allsizes_sum.index, rotation="vertical")
# Out:
# ([<matplotlib.axis.XTick at 0x116e222b0>,
# ...
#  <a list of 53 Text xticklabel objects>)
